# %%
# !pip install geocoder
# !pip install BeautifulSoup4
import numpy as np 
import pandas as pd 
import geocoder 
import requests 
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: geocoder in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: future in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from geocoder) (0.16.0)
# Requirement already satisfied: ratelim in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: six in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from geocoder) (1.11.0)
# Requirement already satisfied: click in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: decorator in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->geocoder) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->geocoder) (2018.10.15)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->geocoder) (2.7)
# Requirement already satisfied: BeautifulSoup4 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (4.6.3)

# %%
URL = "https://www.wikizeroo.org/index.php?q=aHR0cHM6Ly9lbi53aWtpcGVkaWEub3JnL3dpa2kvTGlzdF9vZl9wb3N0YWxfY29kZXNfb2ZfQ2FuYWRhOl9N"
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') 
table = soup.find('div', attrs = {'id':'container'}) 
postalCodes = [];
boroughs= [];
neighborhoods = [];
columnNum = 1;
passVal = False

for row in soup.find_all('td'):
    for cell in row:
        if cell.string and cell.string[0].isalpha() and len(cell.string) > 2:
            passVal = False
            if columnNum == 1:
                if passVal == False and cell.string[1].isdigit():
                    postalCodes.append(cell.string);   
                    columnNum = 2
                else:
                    continue
            elif columnNum == 2 :
                if cell.string == 'Not assigned':
                    passVal = True
                    del postalCodes[-1]
                    columnNum = 1
                    continue
                else:
                    boroughs.append(cell.string);      
                    columnNum = 3
            elif columnNum == 3 :
                if cell.string == 'Not assigned\n':
                    neighborhoods.append(boroughs[-1])
                else:
                    neighborhoods.append(cell.string); 
                columnNum = 1

# %%
column_names = ['PostalCode', 'Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

neighbors = pd.DataFrame(columns=column_names)
lat_lng_coords = None

for data in range(0, len(postalCodes)-1):
    code = postalCodes[data]
    borough = boroughs[data]
    neighborhood_name = neighborhoods[data]
    
    g = geocoder.arcgis('{}, Toronto, Ontario'.format(code))
    lat_lng_coords = g.latlng

    neighbors = neighbors.append({ 'PostalCode': code,
                                   'Borough': borough,
                                   'Neighborhood': neighborhood_name,
                                   'Latitude': lat_lng_coords[0],
                                   'Longitude': lat_lng_coords[1]}, ignore_index=True)
    
neighbors
# Out:
#     PostalCode            Borough  \
# 0         M1A
#       Not assigned
#
# 1         M3A
#         North York
#
# 2         M4A
#         North York
#
# 3         M5A
#   Downtown Toronto
#
# 4         M6A
#         North York
#
# 5         M7A
#   Downtown Toronto
#
# 6         M8A
#       Not assigned
#
# 7         M1B
#        Scarborough
#
# 8         M2B
#       Not assigned
#
# 9         M4B
#          East York
#
# 10        M5B
#   Downtown Toronto
#
# 11        M6B
#         North York
#
# 12        M7B
#       Not assigned
#
# 13        M9B
#          Etobicoke
#
# 14        M1C
#        Scarborough
#
# 15        M2C
#       Not assigned
#
# 16        M4C
#          East York
#
# 17        M5C
#   Downtown Toronto
#
# 18        M6C
#               York
#
# 19        M7C
#       Not assigned
#
# 20        M9C
#          Etobicoke
#
# 21        M1E
#        Scarborough
#
# 22        M2E
#       Not assigned
#
# 23        M4E
#       East Toronto
#
# 24        M5E
#   Downtown Toronto
#
# 25        M6E
#               York
#
# 26        M7E
#       Not assigned
#
# 27        M9E
#       Not assigned
#
# 28        M2G
#       Not assigned
#
# 29        M4G
#          East York
#
# ..         ...                ...
# 105       M2V
#       Not assigned
#
# 106       M4V
#    Central Toronto
#
# 107       M5V
#   Downtown Toronto
#
# 108       M6V
#       Not assigned
#
# 109       M8V
#          Etobicoke
#
# 110       M9V
#          Etobicoke
#
# 111       M1W
#        Scarborough
#
# 112       M2W
#       Not assigned
#
# 113       M4W
#   Downtown Toronto
#
# 114       M5W
#   Downtown Toronto
#
# 115       M6W
#       Not assigned
#
# 116       M8W
#          Etobicoke
#
# 117       M9W
#          Etobicoke
#
# 118       M1X
#        Scarborough
#
# 119       M2X
#       Not assigned
#
# 120       M4X
#   Downtown Toronto
#
# 121       M5X
#   Downtown Toronto
#
# 122       M6X
#       Not assigned
#
# 123       M8X
#          Etobicoke
#
# 124       M9X
#       Not assigned
#
# 125       M2Y
#       Not assigned
#
# 126       M4Y
#   Downtown Toronto
#
# 127       M5Y
#       Not assigned
#
# 128       M7Y
#       East Toronto
#
# 129       M8Y
#          Etobicoke
#
# 130       M9Y
#       Not assigned
#
# 131       M2Z
#       Not assigned
#
# 132       M4Z
#       Not assigned
#
# 133       M6Z
#       Not assigned
#
# 134       M8Z
#          Etobicoke
#
#
#                                           Neighborhood   Latitude  Longitude
# 0                                                 M2A
#   43.648690 -79.385440
# 1                                           Parkwoods
#   43.752420 -79.329242
# 2                                    Victoria Village
#   43.730600 -79.313265
# 3                          Regent Park / Harbourfront
#   43.650295 -79.359166
# 4                   Lawrence Manor / Lawrence Heights
#   43.723270 -79.451286
# 5        Queen's Park / Ontario Provincial Government
#   43.661150 -79.391715
# 6                                                 M9A
#   43.648690 -79.385440
# 7                                     Malvern / Rouge
#   43.811525 -79.195517
# 8                                                 M3B
#   43.648690 -79.385440
# 9                    Parkview Hill / Woodbine Gardens
#   43.707535 -79.311773
# 10                           Garden District, Ryerson
#   43.657363 -79.378180
# 11                                          Glencairn
#   43.707990 -79.448367
# 12                                                M8B
#   43.648690 -79.385440
# 13   West Deane Park / Princess Gardens / Martin Gr...  43.650347 -79.555040
# 14           Rouge Hill / Port Union / Highland Creek
#   43.785665 -79.158725
# 15                                                M3C
#   43.648690 -79.385440
# 16                                   Woodbine Heights
#   43.689640 -79.306874
# 17                                     St. James Town
#   43.651210 -79.375481
# 18                                 Humewood-Cedarvale
#   43.692105 -79.430355
# 19                                                M8C
#   43.648690 -79.385440
# 20   Eringate / Bloordale Gardens / Old Burnhamthor...  43.648573 -79.578250
# 21                Guildwood / Morningside / West Hill
#   43.765815 -79.175193
# 22                                                M3E
#   43.648690 -79.385440
# 23                                        The Beaches
#   43.676531 -79.295425
# 24                                        Berczy Park
#   43.645160 -79.373675
# 25                                Caledonia-Fairbanks
#   43.688640 -79.451018
# 26                                                M8E
#   43.648690 -79.385440
# 27                                                M1G
#   43.648690 -79.385440
# 28                                                M3G
#   43.648690 -79.385440
# 29                                            Leaside
#   43.709495 -79.363989
# ..                                                 ...        ...        ...
# 105                                               M3V
#   43.648690 -79.385440
# 106  Summerhill West / Rathnelly / South Hill / For...  43.686074 -79.402265
# 107  CN Tower / King and Spadina / Railway Lands / ...  43.640815 -79.399538
# 108                                               M7V
#   43.648690 -79.385440
# 109    New Toronto / Mimico South / Humber Bay Shores
#   43.612200 -79.495146
# 110  South Steeles / Silverstone / Humbergate / Jam...  43.743145 -79.584664
# 111                    Steeles West / L'Amoreaux West
#   43.800883 -79.320740
# 112                                               M3W
#   43.648690 -79.385440
# 113                                          Rosedale
#   43.682205 -79.377945
# 114                                    Stn A PO Boxes
#   43.648690 -79.385440
# 115                                               M7W
#   43.648690 -79.385440
# 116                           Alderwood / Long Branch
#   43.601131 -79.538785
# 117                                         Northwest
#   43.711740 -79.579181
# 118                                       Upper Rouge
#   43.834215 -79.216701
# 119                                               M3X
#   43.648690 -79.385440
# 120                      St. James Town / Cabbagetown
#   43.668160 -79.366602
# 121           First Canadian Place / Underground city
#   43.648280 -79.381461
# 122                                               M7X
#   43.648690 -79.385440
# 123  The Kingsway / Montgomery Road  / Old Mill North
#   43.653760 -79.510890
# 124                                               M1Y
#   43.648690 -79.385440
# 125                                               M3Y
#   43.648690 -79.385440
# 126                              Church and Wellesley
#   43.666585 -79.381302
# 127                                               M6Y
#   43.648690 -79.385440
# 128             Business reply mail Processing CentrE
#   43.648690 -79.385440
# 129  Old Mill South / King's Mill Park / Sunnylea /...  43.632835 -79.489550
# 130                                               M1Z
#   43.648690 -79.385440
# 131                                               M3Z
#   43.648690 -79.385440
# 132                                               M5Z
#   43.648690 -79.385440
# 133                                               M7Z
#   43.648690 -79.385440
# 134  Mimico NW / The Queensway West / South of Bloo...  43.624630 -79.526950
#
# [135 rows x 5 columns]

# %%
neighbors.shape
# Out:
# (135, 5)
